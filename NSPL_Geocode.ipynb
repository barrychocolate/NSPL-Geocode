# %% [markdown]
# # Geocoding Greggs Locations Using the National Statistics Postcode Lookup (NSPL) Dataset
#
# In this project, we will load a dataset of Greggs locations and geocode them to coordinates using the National Statistics Postcode Lookup (NSPL) dataset. We will follow these steps:
# 1. Load and preprocess the Greggs dataset.
# 2. Standardise and format postcodes.
# 3. Load and preprocess the NSPL dataset.
# 4. Merge the Greggs dataset with the NSPL to obtain coordinates.
# 5. Visualise the result on an interactive map.
#
# ---
#
# ### Step 1: Import Libraries
# We will begin by importing the necessary libraries for data processing and visualization.

# %%
# Import necessary libraries
import pandas as pd
import geopandas as gpd
import folium

# %% [markdown]
# ---
#
# ### Step 2: Load the Greggs Dataset
# Let's load the `greggs_uk.csv` file, which contains the list of Greggs locations with postcodes. We'll inspect the first few rows to understand its structure.

# %%
# Load the Greggs dataset
greggs_df = pd.read_csv('greggs_uk.csv')

# Display the first few rows of the dataset
greggs_df.head()
# Out:
#     FHRSID BusinessName                 AddressLine1    AddressLine2  \
# 0   597898       Greggs               6 Watford Road      Birmingham
# 1   854057       Greggs  39 One Stop Shopping Centre    Walsall Road
# 2   373168       Greggs              16 Western Road         Romford
# 3  1057556       Greggs                          NaN             NaN
# 4  1291323       Greggs                          NaN  49 High Street
#
#            AddressLine3   AddressLine4  PostCode             BusinessType  \
# 0                   NaN            NaN   B30 1JA        Retailers - other
# 1            Perry Barr     Birmingham   B42 1AA   Takeaway/sandwich shop
# 2                   NaN            NaN   RM1 3LD        Retailers - other
# 3  52-54 Botanic Avenue        Belfast   BT7 1JR  Restaurant/Cafe/Canteen
# 4                 Stone  Staffordshire  ST15 8AD    Manufacturers/packers
#
#   RatingValue
# 0           5
# 1           5
# 2           5
# 3           5
# 4           5

# %% [markdown]
# ---
#
# ### Step 3: Standardise and Format the Postcode Column
# To ensure that our postcodes match the format in the NSPL dataset, we will:
# - Make all postcodes uppercase.
# - Remove any existing spaces.
# - Insert a space before the last three characters to standardize the postcode format.

# %%
# Standardize the postcode column
greggs_df['PostCode'] = greggs_df['PostCode'].str.upper().str.replace(" ", "")
greggs_df['PostCode'] = greggs_df['PostCode'].str[:-3] + \
    " " + greggs_df['PostCode'].str[-3:]

# Display the first few rows to check the formatting
greggs_df.head()
# Out:
#     FHRSID BusinessName                 AddressLine1    AddressLine2  \
# 0   597898       Greggs               6 Watford Road      Birmingham
# 1   854057       Greggs  39 One Stop Shopping Centre    Walsall Road
# 2   373168       Greggs              16 Western Road         Romford
# 3  1057556       Greggs                          NaN             NaN
# 4  1291323       Greggs                          NaN  49 High Street
#
#            AddressLine3   AddressLine4  PostCode             BusinessType  \
# 0                   NaN            NaN   B30 1JA        Retailers - other
# 1            Perry Barr     Birmingham   B42 1AA   Takeaway/sandwich shop
# 2                   NaN            NaN   RM1 3LD        Retailers - other
# 3  52-54 Botanic Avenue        Belfast   BT7 1JR  Restaurant/Cafe/Canteen
# 4                 Stone  Staffordshire  ST15 8AD    Manufacturers/packers
#
#   RatingValue
# 0           5
# 1           5
# 2           5
# 3           5
# 4           5

# %% [markdown]
# ---
#
# ### Step 4: Load the NSPL Dataset
# Now, we'll load the `NSPL21_AUG_2024_UK.csv` file, which contains the NSPL data. We will retain only the necessary columns: `pcds` (postcode), `lat` (latitude), and `long` (longitude).
#
# You will first need to download this from the [ONS Open Geography Portal](https://geoportal.statistics.gov.uk/search?q=PRD_NSPL%20AUG_2024&sort=Date%20Created%7Ccreated%7Cdesc)

# %%
# Load the NSPL dataset
nspl_df = pd.read_csv('NSPL21_AUG_2024_UK.csv')

# Select only the columns we need
nspl_df = nspl_df[['pcds', 'lat', 'long']]

# Display the first few rows of the NSPL dataset
nspl_df.head()
# Out:
# C:\Users\barry\AppData\Local\Temp\ipykernel_36744\1802651139.py:2: DtypeWarning: Columns (21,22,26,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   nspl_df = pd.read_csv('NSPL21_AUG_2024_UK.csv')
#       pcds        lat      long
# 0  AB1 0AA  57.101474 -2.242851
# 1  AB1 0AB  57.102554 -2.246308
# 2  AB1 0AD  57.100556 -2.248342
# 3  AB1 0AE  57.084444 -2.255708
# 4  AB1 0AF  57.096656 -2.258102

# %% [markdown]
# ---
#
# ### Step 5: Merge the Greggs and NSPL Datasets
# We will now join the `greggs_df` and `nspl_df` datasets on the postcode columns to obtain latitude and longitude for each Greggs location.

# %%
# Merge the Greggs dataset with the NSPL dataset on postcode
merged_df = pd.merge(greggs_df, nspl_df, left_on='PostCode',
                     right_on='pcds', how='left')

# Remove rows with missing coordinates
merged_df = merged_df.dropna(subset=['lat', 'long'])

# Display the first few rows of the merged dataset
merged_df.head()
# Out:
#     FHRSID BusinessName                 AddressLine1    AddressLine2  \
# 0   597898       Greggs               6 Watford Road      Birmingham
# 1   854057       Greggs  39 One Stop Shopping Centre    Walsall Road
# 2   373168       Greggs              16 Western Road         Romford
# 3  1057556       Greggs                          NaN             NaN
# 4  1291323       Greggs                          NaN  49 High Street
#
#            AddressLine3   AddressLine4  PostCode             BusinessType  \
# 0                   NaN            NaN   B30 1JA        Retailers - other
# 1            Perry Barr     Birmingham   B42 1AA   Takeaway/sandwich shop
# 2                   NaN            NaN   RM1 3LD        Retailers - other
# 3  52-54 Botanic Avenue        Belfast   BT7 1JR  Restaurant/Cafe/Canteen
# 4                 Stone  Staffordshire  ST15 8AD    Manufacturers/packers
#
#   RatingValue      pcds        lat      long
# 0           5   B30 1JA  52.416523 -1.930140
# 1           5   B42 1AA  52.517615 -1.902940
# 2           5   RM1 3LD  51.576851  0.182899
# 3           5   BT7 1JR  54.587208 -5.932365
# 4           5  ST15 8AD  52.902867 -2.147497

# %% [markdown]
# ---
#
# ### Step 6: Convert to GeoDataFrame for Mapping
# To visualize our data on a map, we will convert the `merged_df` DataFrame to a GeoDataFrame, using `geopandas`.

# %%
# Convert to GeoDataFrame
gdf = gpd.GeoDataFrame(merged_df, geometry=gpd.points_from_xy(
    merged_df['long'], merged_df['lat']))

# %% [markdown]
# ---
#
# ### Step 7: Visualise Greggs Locations on a Map
# Using Folium, we will create an interactive map of Greggs locations across the UK. Each location will be marked with a popup showing the postcode.

# %%
# Initialize a Folium map centered around Manchester
uk_map = folium.Map(location=[53.483959, -2.244644], zoom_start=15)

# Add each Greggs location to the map with name, address, and rating in the popup
for idx, row in gdf.iterrows():
    popup_text = f"""
    <b>Name:</b> {row['BusinessName']}<br>
    <b>Address:</b> {row['AddressLine1']}<br>
    <b>Business Type:</b> {row['BusinessType']}<br>
    <b>Rating:</b> {row['RatingValue']}
    """
    folium.Marker(
        location=[row['lat'], row['long']],
        popup=popup_text
    ).add_to(uk_map)

# Display the map
uk_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e06d03c559734f38a8bd23a017536dc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e06d03c559734f38a8bd23a017536dc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1e06d03c559734f38a8bd23a017536dc = L.map(
#                 &quot;map_1e06d03c559734f38a8bd23a017536dc&quot;,
#                 {
#                     center: [53.483959, -2.244644],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2cfe2b31207226ad8146de44de1d0d21 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2cfe2b31207226ad8146de44de1d0d21.addTo(map_1e06d03c559734f38a8bd23a017536dc);
#
#
#             var marker_66a55a521bd4091da06d72ff5a1b15a1 = L.marker(
#                 [52.416523, -1.93014],
#                 {}
#             ).addTo(map_1e06d03c559734f38a8bd23a017536dc);
#
#
#         var popup_fc90916c2b7139941baef02894505129 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_edf06d4581d159c6753f5ddd8579fbfc = $(`&lt;div id=&quot;html_edf06d4581d159c6753f5ddd8579fbfc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Name:&lt;/b&gt; Greggs&lt;br&gt;     &lt;b&gt;Address:&lt;/b&gt; 6 Watford Road&lt;br&gt;     &lt;b&gt;Business Type:&lt;/b&gt; Retailers - other&lt;br&gt;     &lt;b&gt;Rating:&lt;/b&gt; 5     &lt;/div&gt;`)[0];
#                 popup_fc90916c2b7139941baef02894505129.setContent(html_edf06d4581d159c6753f5ddd8579fbfc);
#
#
#
#         marker_66a55a521bd4091da06d72ff5a1b15a1.bindPopup(popup_fc90916c2b7139941baef02894505129)
#         ;
#
#
#
#
#             var marker_eb7e741370ec796f93eb1e69425e0066 = L.marker(
#                 [52.517615, -1.90294],
#                 {}
#             ).addTo(map_1e06d03c559734f38a8bd23a017536dc);
#
#
#         var popup_0ac02caa8d56e5a7904d4a52bd781f70 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_edac99c63aca5c81f61b22f3d9461a86 = $(`&lt;div id=&quot;html_edac99c63aca5c81f61b22f3d9461a86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Name:&lt;/b&gt; Greggs&lt;br&gt;     &lt;b&gt;Address:&lt;/b&gt; 39 One Stop Shopping Centre&lt;br&gt;     &lt;b&gt;Business Type:&lt;/b&gt; Takeaway/sandwich shop&lt;br&gt;     &lt;b&gt;Rating:&lt;/b&gt; 5     &lt;/div&gt;`)[0];
#                 popup_0ac02caa8d56e5a7904d4a52bd781f70.setContent(html_edac99c63aca5c81f61b22f3d9461a86);
#
#
#
#         marker_eb7e741370ec796f93eb1e69425e0066.bindPopup(popup_0ac02caa8d56e5a7904d4a52bd781f70)
#         ;
#
#
#
#
#             var marker_8aade5b652f0469dcdad5cf0f12ae763 = L.marker(
#                 [51.576851, 0.182899],
#                 {}
#             ).addTo(map_1e06d03c559734f38a8bd23a017536dc);
#
#
#         var popup_c34eef3c6e6d19c76a294a0b0c75c93b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c3025b09513cb87da7771db9e8654a8 = $(`&lt;div id=&quot;html_0c3025b09513cb87da7771db9e8654a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Name:&lt;/b&gt; Greggs&lt;br&gt;     &lt;b&gt;Address:&lt;/b&gt; 16 Western Road&lt;br&gt;     &lt;b&gt;Business Type:&lt;/b&gt; Retailers - other&lt;br&gt;     &lt;b&gt;Rating:&lt;/b&gt; 5     &lt;/div&gt;`)[0];
#                 popup_c34eef3c6e6d19c76a294a0b0c75c93b.setContent(html_0c3025b09513cb87da7771db9e8654a8);
#
#
#
#         marker_8aade5b652f0469dcdad5cf0f12ae763.bindPopup(popup_c34eef3c6e6d19c76a294a0b0c75c93b)
#         ;
#
#
#
#
#             var marker_b2878d58ba70073f417734d39aef09c5 = L.marker(
#                 [54.587208, -5.932365],
#                 {}
#             ).addTo(map_1e06d03c559734f38a8bd23a017536dc);
#
#
#         var popup_1e479c14e3f436b0fe7b79fb25f221e0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_45ca1ea0e1ad51e8ce5cd19ea2529a4e = $(`&lt;div id=&quot;html_45ca1ea0e1ad51e8ce5cd19ea2529a4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Name:&lt;/b&gt; Greggs&lt;br&gt;     &lt;b&gt;Address:&lt;/b&gt; nan&lt;br&gt;     &lt;b&gt;Business Type:&lt;/b&gt; Restaurant/Cafe/Canteen&lt;br&gt;     &lt;b&gt;Rating:&lt;/b&gt; 5     &lt;/div&gt;`)[0];
#                 popup_1e479c14e3f436b0fe7b79fb25f221e0.setContent(html_45ca1ea0e1ad51e8ce5cd19ea2529a4e);
#
#
#
#         marker_b2878d58ba70073f417734d39aef09c5.bindPopup(popup_1e479c14e3f436b0fe7b79fb25f221e0)
#         ;
#
#
#
#
#             var marker_099f459b0ff93b15506a70ac96b89903 = L.marker(
#                 [52.902867, -2.147497],
#                 {}
#             ).addTo(map_1e06d03c559734f38a8bd23a017536dc);

# %% [markdown]
# ---
#
# ### Step 8: Save and View the Map
# Finally, we'll save the map as an HTML file, so you can open it in a web browser and explore Greggs locations interactively.

# %%
# Save the map to an HTML file
uk_map.save("greggs_locations_map.html")
print("Map has been saved as 'greggs_locations_map.html'")
# Out:
# Map has been saved as 'greggs_locations_map.html'

# %% [markdown]
# ---
#
# ### Conclusion
# In this project, we successfully geocoded Greggs locations using the NSPL dataset and visualised them on an interactive map. This technique can be applied to other datasets with postcodes to enhance spatial analysis and visualization.
